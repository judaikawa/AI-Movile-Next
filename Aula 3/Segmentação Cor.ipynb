# %%
import cv2
# Aqui vc pode ver todos os espaços de cor
color_flags = [i for i in dir(cv2) if i.startswith('COLOR_')]

# %%
len(color_flags)
# Out:
# 274

# %%
color_flags[4]
# Out:
# 'COLOR_BAYER_BG2GRAY'

# %% [markdown]
# # Segmentação pelo espaço de cor

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread('chame.png')
plt.imshow(img)
plt.show()

# %%
img2 = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img2)
plt.show()

# %% [markdown]
# ## Visualização do charmander no espaço de cor

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from matplotlib import colors

# %%
# %matplotlib inline
r, g, b = cv2.split(img2)
fig = plt.figure()
axis = fig.add_subplot(1,1,1,projection='3d')
pixel_colors = img2.reshape((np.shape(img2)[0]*np.shape(img2)[1],3))

norm = colors.Normalize(vmin=-1., vmax=1.)

norm.autoscale(pixel_colors)

pixel_colors = norm(pixel_colors).tolist()

axis.scatter(r.flatten(), g.flatten(), b.flatten(), facecolors=pixel_colors, marker=".")

axis.set_xlabel("Red")
axis.set_ylabel("Green")
axis.set_zlabel("Blue")
plt.show()

# %% [markdown]
# # Visualização do espaço de cor em HSV
# Hue, Saturation and Value

# %%
hsv_img2 = cv2.cvtColor(img2, cv2.COLOR_RGB2HSV)
h, s, v = cv2.split(hsv_img2)
fig = plt.figure()
axis = fig.add_subplot(1,1,1,projection='3d')
